# %%
Name:- Rajratna Vijay Bhosale
Roll NO:- 23091003
Class:- MSc I Year

# %% [markdown]
# **Polynomial Plotting with Annotations:
# Randomly select the coefficients of a 5th degree polynomial. Set the random seed as the last two
# digits of your roll number. Plot the polynomial for -5 ≤ x ≤ 5. Annotate the plot to identify the
# maxima and minima of the polynomial.**

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(3)  
coefficients = np.random.randint(-10, 10, size=6)
def polynomial(x, coeffs):
    return np.polyval(coeffs, x)
x_values = np.linspace(-5, 5, 1000)
y_values = polynomial(x_values, coefficients)
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label='Polynomial')
maxima_x = x_values[np.argmax(y_values)]
maxima_y = np.max(y_values)
minima_x = x_values[np.argmin(y_values)]
minima_y = np.min(y_values)
plt.scatter([maxima_x, minima_x], [maxima_y, minima_y], color='red')
plt.annotate(f'Maxima\n({maxima_x:.2f}, {maxima_y:.2f})', xy=(maxima_x, maxima_y), xytext=(maxima_x + 1, maxima_y + 50),
             arrowprops=dict(facecolor='black', arrowstyle='->'), fontsize=10, color='red')
plt.annotate(f'Minima\n({minima_x:.2f}, {minima_y:.2f})', xy=(minima_x, minima_y), xytext=(minima_x - 1, minima_y - 50),
             arrowprops=dict(facecolor='black', arrowstyle='->'), fontsize=10, color='red')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of a 5th Degree Polynomial with Maxima and Minima Annotations')
plt.legend()
plt.grid(True)
plt.show()
